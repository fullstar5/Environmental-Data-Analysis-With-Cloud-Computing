# %%
from elasticsearch import Elasticsearch
from plot import plot_data, merge_bom_epa, create_heatmap, plot_air_quality_and_sentiment
import ipywidgets as widgets
from IPython.display import display, clear_output
from get_data import twitter, epa, bom, health
import pandas as pd

# %%
es = Elasticsearch(
    'https://127.0.0.1:9200',
    verify_certs=False,
    basic_auth=('elastic', 'elastic'),
    request_timeout=60,
    ssl_show_warn=False
    )

# %%
city = None

city_textbox = widgets.Text(
    value='Melbourne',
    description='City:',
    disabled=False
)

button = widgets.Button(description="Update Plot")

def on_button_clicked(b):
    global city  
    city = city_textbox.value  
    clear_output(wait=True)  
    display(city_textbox, button)  
    plot_data(es, start=1, end=10, city=city, size=1000)  

button.on_click(on_button_clicked)

display(city_textbox, button)
# Out:
# Text(value='Ballarat', description='City:')
# Button(description='Update Plot', style=ButtonStyle())

# %%
epa_data = epa(es, start=3, end=10, size=2000)
bom_data = bom(es, start=3, end=10, size=2000)

# %%
print(epa_data)
print(bom_data)

# %%
data_epa = [{**item['_source'], 'date': item['_index']} for item in epa_data]
# data_epa = [item['_source'] for item in epa_data]
epa_df = pd.DataFrame(data_epa)
print(epa_df)
# Out:
#           hour         siteName                coordinates  averageValue  \
# 0     01:00:00         Box Hill    [-37.8287277, 145.1324]      9.180000
# 1     01:00:00       Alphington    [-37.7784081, 145.0306]      9.790000
# 2     01:00:00        Churchill  [-38.3043137, 146.414932]      2.500000
# 3     01:00:00  Traralgon South      [-38.29585, 146.5392]      5.470000
# 4     01:00:00        Traralgon  [-38.1942825, 146.531464]      1.610000
# ...        ...              ...                        ...           ...
# 1995  23:00:00          Kyneton    [-37.24706, 144.451111]      8.344532
# 1996  23:00:00        Heathcote    [-36.92107, 144.709946]      8.344532
# 1997  23:00:00         Kinglake  [-37.5337448, 145.340515]      8.344532
# 1998  23:00:00       Daylesford  [-37.3410339, 144.130463]      9.480000
# 1999  23:00:00          Heywood  [-38.1323051, 141.631821]      8.368691
#
#      healthParameter healthAdvice                        date
# 0              PM2.5         Good  epa-air-quality-2024-05-03
# 1              PM2.5         Good  epa-air-quality-2024-05-03
# 2              PM2.5         Good  epa-air-quality-2024-05-03
# 3          Particles         Good  epa-air-quality-2024-05-03
# 4              PM2.5         Good  epa-air-quality-2024-05-03
# ...              ...          ...                         ...
# 1995           PM2.5         Good  epa-air-quality-2024-05-03
# 1996           PM2.5         Good  epa-air-quality-2024-05-03
# 1997           PM2.5         Good  epa-air-quality-2024-05-03
# 1998       Particles         Good  epa-air-quality-2024-05-03
# 1999           PM2.5         Good  epa-air-quality-2024-05-03
#
# [2000 rows x 7 columns]

# %%
data_bom = [item['_source'] for item in bom_data]
bom_df = pd.DataFrame(data_bom)
print(bom_df)
# Out:
#                     site_name local_date_time     coordinates  \
# 0    Melbourne (Olympic Park)  20240503153000  [-37.8, 145.0]
# 1           Melbourne Airport  20240503153000  [-37.7, 144.8]
# 2    Melbourne (Olympic Park)  20240503160000  [-37.8, 145.0]
# 3           Melbourne Airport  20240503160000  [-37.7, 144.8]
# 4    Melbourne (Olympic Park)  20240503170000  [-37.8, 145.0]
# ..                        ...             ...             ...
# 349         Melbourne Airport  20240510210000  [-37.7, 144.8]
# 350  Melbourne (Olympic Park)  20240510220000  [-37.8, 145.0]
# 351         Melbourne Airport  20240510220000  [-37.7, 144.8]
# 352  Melbourne (Olympic Park)  20240510230000  [-37.8, 145.0]
# 353         Melbourne Airport  20240510230000  [-37.7, 144.8]
#
#      apparent_temperature          cloud cloud_type  delta_temperature  \
# 0                    15.8              -          -                3.0
# 1                    14.0          Clear          -                4.4
# 2                    15.6              -          -                2.9
# 3                    13.6              -          -                4.1
# 4                    15.5              -          -                2.1
# ..                    ...            ...        ...                ...
# 349                  12.6  Mostly cloudy          -                0.3
# 350                  15.7              -          -                0.0
# 351                  14.3   Mostly clear    Stratus                0.3
# 352                  15.3              -          -                0.0
# 353                  12.4   Mostly clear    Stratus                0.3
#
#      air_temperature  dew_point   press press_tend rain_trace swell_period  \
# 0               16.6       10.9  1027.2          -        0.0         None
# 1               16.9        8.3  1027.2          -        0.2         None
# 2               16.6       11.1  1027.0          -        0.0         None
# 3               16.7        8.7  1027.1          -        0.2         None
# 4               15.4       11.4  1026.7          -        0.0         None
# ..               ...        ...     ...        ...        ...          ...
# 349             13.7       13.2  1028.8          F        1.0         None
# 350             14.3       14.3  1028.6          -        0.6         None
# 351             13.7       13.1  1029.0          -        1.0         None
# 352             14.0       14.0  1028.4          -        0.6         None
# 353             13.3       12.7  1028.5          -        1.2         None
#
#     vis_km  weather  wind_spd_kmh
# 0       10     Fine             6
# 1       10     Fine            13
# 2       10     Fine             7
# 3       10     Fine            15
# 4       10     Fine             2
# ..     ...      ...           ...
# 349     15  Drizzle            11
# 350     10     Fine             0
# 351     10     Fine             2
# 352     10     Fine             0
# 353     10     Fine             9
#
# [354 rows x 16 columns]

# %%
merged_df = merge_bom_epa(bom_df=bom_df, epa_df=epa_df)
print(merged_df)
# Out:
#                      site_name     local_date_time coordinates_bom  \
# 0     Melbourne (Olympic Park) 2024-05-03 15:30:00  [-37.8, 145.0]
# 1     Melbourne (Olympic Park) 2024-05-03 15:30:00  [-37.8, 145.0]
# 2     Melbourne (Olympic Park) 2024-05-03 15:30:00  [-37.8, 145.0]
# 3     Melbourne (Olympic Park) 2024-05-03 15:30:00  [-37.8, 145.0]
# 4     Melbourne (Olympic Park) 2024-05-03 15:30:00  [-37.8, 145.0]
# ...                        ...                 ...             ...
# 1445         Melbourne Airport 2024-05-03 23:00:00  [-37.7, 144.8]
# 1446         Melbourne Airport 2024-05-03 23:00:00  [-37.7, 144.8]
# 1447         Melbourne Airport 2024-05-03 23:00:00  [-37.7, 144.8]
# 1448         Melbourne Airport 2024-05-03 23:00:00  [-37.7, 144.8]
# 1449         Melbourne Airport 2024-05-03 23:00:00  [-37.7, 144.8]
#
#       apparent_temperature cloud cloud_type  delta_temperature  \
# 0                     15.8     -          -                3.0
# 1                     15.8     -          -                3.0
# 2                     15.8     -          -                3.0
# 3                     15.8     -          -                3.0
# 4                     15.8     -          -                3.0
# ...                    ...   ...        ...                ...
# 1445                   4.6     -          -                0.6
# 1446                   4.6     -          -                0.6
# 1447                   4.6     -          -                0.6
# 1448                   4.6     -          -                0.6
# 1449                   4.6     -          -                0.6
#
#       air_temperature  dew_point   press  ... vis_km weather wind_spd_kmh  \
# 0                16.6       10.9  1027.2  ...     10    Fine            6
# 1                16.6       10.9  1027.2  ...     10    Fine            6
# 2                16.6       10.9  1027.2  ...     10    Fine            6
# 3                16.6       10.9  1027.2  ...     10    Fine            6
# 4                16.6       10.9  1027.2  ...     10    Fine            6
# ...               ...        ...     ...  ...    ...     ...          ...
# 1445              7.9        6.5  1027.5  ...     10    Fine           13
# 1446              7.9        6.5  1027.5  ...     10    Fine           13
# 1447              7.9        6.5  1027.5  ...     10    Fine           13
# 1448              7.9        6.5  1027.5  ...     10    Fine           13
# 1449              7.9        6.5  1027.5  ...     10    Fine           13
#
#             date hour         siteName            coordinates_epa  \
# 0     2024-05-03   15         Box Hill    [-37.8287277, 145.1324]
# 1     2024-05-03   15       Alphington    [-37.7784081, 145.0306]
# 2     2024-05-03   15        Churchill  [-38.3043137, 146.414932]
# 3     2024-05-03   15  Traralgon South      [-38.29585, 146.5392]
# 4     2024-05-03   15        Traralgon  [-38.1942825, 146.531464]
# ...          ...  ...              ...                        ...
# 1445  2024-05-03   23          Kyneton    [-37.24706, 144.451111]
# 1446  2024-05-03   23        Heathcote    [-36.92107, 144.709946]
# 1447  2024-05-03   23         Kinglake  [-37.5337448, 145.340515]
# 1448  2024-05-03   23       Daylesford  [-37.3410339, 144.130463]
# 1449  2024-05-03   23          Heywood  [-38.1323051, 141.631821]
#
#       averageValue healthParameter healthAdvice
# 0         5.200000           PM2.5         Good
# 1        27.480000           PM2.5         Fair
# 2         1.080000           PM2.5         Good
# 3         7.350000       Particles         Good
# 4        12.830000           PM2.5         Good
# ...            ...             ...          ...
# 1445      8.344532           PM2.5         Good
# 1446      8.344532           PM2.5         Good
# 1447      8.344532           PM2.5         Good
# 1448      9.480000       Particles         Good
# 1449      8.368691           PM2.5         Good
#
# [1450 rows x 23 columns]

# %%
weather_columns = ['apparent_temperature', 'delta_temperature', 'air_temperature', 'dew_point', 'wind_spd_kmh']
air_quality_columns = ['averageValue']

create_heatmap(merged_df, weather_columns, air_quality_columns)

# %%
city = "Ballarat"

# %%
twitter_data = twitter(es, city=city, size=2000)
epa_data = epa(es, start=3, end=14, city=city, size=2000)

# %%
print(twitter_data)
# Out:
# [{'_index': 'twitter_vic', '_id': '6122C277-596B-4BAD-9D25-6A089ED25459', '_score': 3.99325, '_source': {'sentiment': -0.08333333333333333, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '8C7C404B-8545-4BDC-98E0-93DA2313990A', '_score': 3.99325, '_source': {'sentiment': 0.044444444444444446, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': 'DFA91138-7954-4921-93D2-A340401F29DB', '_score': 3.99325, '_source': {'sentiment': 0.0425531914893617, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': 'C65A48A5-A6B5-4629-ABCE-02550C470CD0', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '8992C511-8F8B-48B8-9C56-72A5244C8683', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '69A7FEB3-3A87-424F-84A6-CAB64AA4DB6B', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '3026F3DA-4887-4AE3-A42F-DAF78E0784F8', '_score': 3.99325, '_source': {'sentiment': 0.2564102564102564, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '9B19C61D-96D5-4FC2-8D72-C1DA8B54E0A5', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '27931249-30D2-491F-9DBE-4C998F9CBBE4', '_score': 3.99325, '_source': {'sentiment': 0.1, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': 'C2B7D506-8CBB-4C7D-9CC9-EF6F758385B8', '_score': 3.99325, '_source': {'sentiment': 0.11764705882352941, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '055002E6-80E6-4228-8BB6-6CB4A0AD814E', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '8258A2CC-6246-4BA7-BE24-2CD6001957FA', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': 'B53AC81C-ADCA-48F6-9888-8F999BED680F', '_score': 3.99325, '_source': {'sentiment': 0.02, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '7B72B1F6-9CFE-4AB2-B47B-F51C0A4E88EA', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '5CEABB91-3A7C-46AE-8A8C-DB401D352B32', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '2B302C9B-63A6-476B-8864-747533E9B344', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '0662D870-212D-44CF-BFF8-3E9B9BD20E2C', '_score': 3.99325, '_source': {'sentiment': -0.18181818181818182, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': 'F5FA66BB-2D60-4B70-991C-AD331242320E', '_score': 3.99325, '_source': {'sentiment': 0.037037037037037035, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '999CBA48-A2BE-4A2B-89F8-1A0DE45CA258', '_score': 3.99325, '_source': {'sentiment': 0.5, 'full_name': 'Ballarat', 'language': 'cy'}}, {'_index': 'twitter_vic', '_id': '3BF775E0-30B9-44E5-BAFE-4F1611D25DBA', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'hu'}}, {'_index': 'twitter_vic', '_id': '9F31C9F0-A6AE-44B9-9DD0-53A141278E0A', '_score': 3.99325, '_source': {'sentiment': -0.2857142857142857, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '4C71BBB1-208D-49FD-8570-F2F408F7B30C', '_score': 3.99325, '_source': {'sentiment': 0.02857142857142857, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id': '1605983A-CCE5-41CA-8EBC-D40845F721D8', '_score': 3.99325, '_source': {'sentiment': 0, 'full_name': 'Ballarat', 'language': 'en'}}, {'_index': 'twitter_vic', '_id':  ...

# %%
data_twitter = [item['_source'] for item in twitter_data]
twitter_df = pd.DataFrame(data_twitter)

data_epa = [{**item['_source'], 'date': item['_index']} for item in epa_data]
epa_df = pd.DataFrame(data_epa)

# %%
print(epa_df)
# Out:
#          hour  siteName                coordinates  averageValue  \
# 0    03:00:00  Ballarat  [-37.5293274, 143.842438]      6.000000
# 1    01:00:00  Ballarat  [-37.5293274, 143.842438]      6.940000
# 2    02:00:00  Ballarat  [-37.5293274, 143.842438]      7.130000
# 3    00:00:00  Ballarat  [-37.5293274, 143.842438]      7.920000
# 4    14:00:00  Ballarat  [-37.5293274, 143.842438]      6.430000
# ..        ...       ...                        ...           ...
# 252  00:00:00  Ballarat  [-37.5293274, 143.842438]      4.900000
# 253  02:00:00  Ballarat  [-37.5293274, 143.842438]      2.530438
# 254  03:00:00  Ballarat  [-37.5293274, 143.842438]      4.650000
# 255  04:00:00  Ballarat  [-37.5293274, 143.842438]      2.505398
# 256  05:00:00  Ballarat  [-37.5293274, 143.842438]      4.680000
#
#     healthParameter healthAdvice                        date
# 0         Particles         Good  epa-air-quality-2024-05-13
# 1         Particles         Good  epa-air-quality-2024-05-13
# 2         Particles         Good  epa-air-quality-2024-05-13
# 3         Particles         Good  epa-air-quality-2024-05-13
# 4         Particles         Good  epa-air-quality-2024-05-13
# ..              ...          ...                         ...
# 252       Particles         Good  epa-air-quality-2024-05-14
# 253           PM2.5         Good  epa-air-quality-2024-05-14
# 254       Particles         Good  epa-air-quality-2024-05-14
# 255           PM2.5         Good  epa-air-quality-2024-05-14
# 256       Particles         Good  epa-air-quality-2024-05-14
#
# [257 rows x 7 columns]

# %%
plot_air_quality_and_sentiment(epa_df, twitter_df, city)

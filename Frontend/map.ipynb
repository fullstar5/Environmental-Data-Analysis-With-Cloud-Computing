# %%
import folium

min_lon, max_lon = 140, 150
min_lat, max_lat = -39, -34

m = folium.Map(
    location=[-36.5, 145],
    zoom_start=6,
    max_bounds=True,
    min_zoom=6.8,
)

folium.GeoJson(
    'vicborder.json',
    name='geojson',
    style_function=lambda x: {
        'fillColor': '#b3d1ff',  
        'color': '#b3d1ff',      
        'fillOpacity': 0.5,      
        'weight': 2              
    }
).add_to(m)

m.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 26
#      13 folium.GeoJson(
#      14     'vicborder.json',
#      15     name='geojson',
#    (...)
#      21     }
#      22 ).add_to(m)
#      24 m.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])
# ---> 26 m
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File ~/.local/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File /usr/local/lib/python3.10/dist-packages/folium/folium.py:321, in Map._repr_html_(self, **kwargs)
#     319     self._parent = None
#     320 else:
# --> 321     out = self._parent._repr_html_(**kwargs)
#     322 return out
#
# File /usr/local/lib/python3.10/dist-packages/branca/element.py:369, in Figure._repr_html_(self, **kwargs)
#     367 def _repr_html_(self, **kwargs):
#     368     """Displays the Figure in a Jupyter notebook."""
# --> 369     html = escape(self.render(**kwargs))
#     370     if self.height is None:
#     371         iframe = (
#     372             '<div style="width:{width};">'
#     373             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     379             "</div></div>"
#     380         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File /usr/local/lib/python3.10/dist-packages/branca/element.py:364, in Figure.render(self, **kwargs)
#     362 """Renders the HTML representation of the element."""
#     363 for name, child in self._children.items():
# --> 364     child.render(**kwargs)
#     365 return self._template.render(this=self, kwargs=kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/folium/folium.py:403, in Map.render(self, **kwargs)
#     376 figure.header.add_child(
#     377     Element(
#     378         "<style>html, body {"
#    (...)
#     386     name="css_style",
#     387 )
#     389 figure.header.add_child(
#     390     Element(
#     391         "<style>#map {"
#    (...)
#     400     name="map_style",
#     401 )
# --> 403 super().render(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/folium/elements.py:25, in JSCSSMixin.render(self, **kwargs)
#      22 for name, url in self.default_css:
#      23     figure.header.add_child(CssLink(url), name=name)
# ---> 25 super().render(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/branca/element.py:681, in MacroElement.render(self, **kwargs)
#     678     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     680 for name, element in self._children.items():
# --> 681     element.render(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/folium/features.py:831, in GeoJson.render(self, **kwargs)
#     829     if self.highlight:
#     830         self.highlight_map = mapper.get_highlight_map(self.highlight_function)
# --> 831 super().render()
#
# File /usr/local/lib/python3.10/dist-packages/folium/map.py:63, in Layer.render(self, **kwargs)
#      55 if self.show:
#      56     self.add_child(
#      57         ElementAddToElement(
#      58             element_name=self.get_name(),
#    (...)
#      61         name=self.get_name() + "_add",
#      62     )
# ---> 63 super().render(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/branca/element.py:678, in MacroElement.render(self, **kwargs)
#     676 script = self._template.module.__dict__.get("script", None)
#     677 if script is not None:
# --> 678     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     680 for name, element in self._children.items():
#     681     element.render(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/branca/element.py:63, in Element.__init__(self, template, template_name)
#      60 self._template_name = template_name
#      62 if template is not None:
# ---> 63     self._template = Template(template)
#      64 elif template_name is not None:
#      65     self._template = ENV.get_template(template_name)
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:1208, in Template.__new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1161 def __new__(
#    1162     cls,
#    1163     source: t.Union[str, nodes.Template],
#    (...)
#    1181     enable_async: bool = False,
#    1182 ) -> t.Any:  # it returns a `Template`, but this breaks the sphinx build...
#    1183     env = get_spontaneous_environment(
#    1184         cls.environment_class,  # type: ignore
#    1185         block_start_string,
#    (...)
#    1206         enable_async,
#    1207     )
# -> 1208     return env.from_string(source, template_class=cls)
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:1105, in Environment.from_string(self, source, globals, template_class)
#    1103 gs = self.make_globals(globals)
#    1104 cls = template_class or self.template_class
# -> 1105 return cls.from_code(self, self.compile(source), gs, None)
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:760, in Environment.compile(self, source, name, filename, raw, defer_init)
#     758 if isinstance(source, str):
#     759     source_hint = source
# --> 760     source = self._parse(source, name, filename)
#     761 source = self._generate(source, name, filename, defer_init=defer_init)
#     762 if raw:
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:617, in Environment._parse(self, source, name, filename)
#     613 def _parse(
#     614     self, source: str, name: t.Optional[str], filename: t.Optional[str]
#     615 ) -> nodes.Template:
#     616     """Internal parsing function used by `parse` and `compile`."""
# --> 617     return Parser(self, source, name, filename).parse()
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/parser.py:60, in Parser.__init__(self, environment, source, name, filename, state)
#      51 def __init__(
#      52     self,
#      53     environment: "Environment",
#    (...)
#      57     state: t.Optional[str] = None,
#      58 ) -> None:
#      59     self.environment = environment
# ---> 60     self.stream = environment._tokenize(source, name, filename, state)
#      61     self.name = name
#      62     self.filename = filename
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/environment.py:667, in Environment._tokenize(self, source, name, filename, state)
#     663 """Called by the parser to do the preprocessing and filtering
#     664 for all the extensions.  Returns a :class:`~jinja2.lexer.TokenStream`.
#     665 """
#     666 source = self.preprocess(source, name, filename)
# --> 667 stream = self.lexer.tokenize(source, name, filename, state)
#     669 for ext in self.iter_extensions():
#     670     stream = ext.filter_stream(stream)  # type: ignore
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/lexer.py:611, in Lexer.tokenize(self, source, name, filename, state)
#     609 """Calls tokeniter + tokenize and wraps it in a token stream."""
#     610 stream = self.tokeniter(source, name, filename, state)
# --> 611 return TokenStream(self.wrap(stream, name, filename), name, filename)
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/lexer.py:335, in TokenStream.__init__(self, generator, name, filename)
#     333 self.closed = False
#     334 self.current = Token(1, TOKEN_INITIAL, "")
# --> 335 next(self)
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/lexer.py:389, in TokenStream.__next__(self)
#     387 elif self.current.type is not TOKEN_EOF:
#     388     try:
# --> 389         self.current = next(self._iter)
#     390     except StopIteration:
#     391         self.close()
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/lexer.py:622, in Lexer.wrap(self, stream, name, filename)
#     613 def wrap(
#     614     self,
#     615     stream: t.Iterable[t.Tuple[int, str, str]],
#     616     name: t.Optional[str] = None,
#     617     filename: t.Optional[str] = None,
#     618 ) -> t.Iterator[Token]:
#     619     """This is called with the stream as returned by `tokenize` and wraps
#     620     every token in a :class:`Token` and converts the value.
#     621     """
# --> 622     for lineno, token, value_str in stream:
#     623         if token in ignored_tokens:
#     624             continue
#
# File /usr/local/lib/python3.10/dist-packages/jinja2/lexer.py:704, in Lexer.tokeniter(self, source, name, filename, state)
#     701 while True:
#     702     # tokenizer loop
#     703     for regex, tokens, new_state in statetokens:
# --> 704         m = regex.match(source, pos)
#     706         # if no match we try again with the next rule
#     707         if m is None:
#
# KeyboardInterrupt:
